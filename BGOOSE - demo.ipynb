# %%
import os
import mne
import glob
import joblib
import logging
import numpy as np
import pandas as pd
import scipy.signal as sp_sig
import scipy.stats as sp_stats
import antropy as ant
from mne.filter import filter_data
from scipy.stats import zscore
from sklearn.preprocessing import robust_scale
from sklearn.metrics import accuracy_score
from imblearn.pipeline import make_pipeline
from imblearn.pipeline import Pipeline
from imblearn.over_sampling import SMOTE
from lightgbm import LGBMClassifier
from joblib import dump, load
from yasa import sliding_window, bandpower_from_psd_ndarray
import time

# %% [markdown]
# # define feature extraction algorithm and parameters

# %%
## feature extraction def
def feature_lfp(epochs, sf, bands, kwargs_welch, freq_broad):
    # Calculate standard descriptive statistics
    hmob, hcomp = ant.hjorth_params(epochs, axis=1)
    feat = {
                    'std': np.std(epochs, ddof=1, axis=1),
                    'iqr': sp_stats.iqr(epochs, rng=(25, 75), axis=1),
                    'skew': sp_stats.skew(epochs, axis=1),
                    'kurt': sp_stats.kurtosis(epochs, axis=1),
                    'nzc': ant.num_zerocross(epochs, axis=1),
                    'hmob': hmob,
                    'hcomp': hcomp
                }
    # power band
    freqs, psd = sp_sig.welch(epochs, sf, **kwargs_welch)
    bp = bandpower_from_psd_ndarray(psd, freqs, bands=bands, relative = True)
    for j, (_, _, b) in enumerate(bands):
        feat[b] = bp[j]
        
    # power ratio
    Gamma = feat['lGamma'] + feat['hGamma']
    Beta = feat['lBeta'] + feat['hBeta']
    feat['dt'] = feat['Delta'] / feat['Theta']
    feat['da'] = feat['Delta'] / feat['Alpha']
    feat['db'] = feat['Delta'] / Beta
    feat['dg'] = feat['Delta'] / Gamma
    feat['ta'] = feat['Theta'] / feat['Alpha']
    feat['tb'] = feat['Theta'] / Beta
    feat['tg'] = feat['Theta'] / Gamma
    feat['ab'] = feat['Alpha'] / Beta
    feat['ag'] = feat['Alpha'] / Gamma
    feat['bg'] = Beta / Gamma
    
    # total power
    idx_broad = np.logical_and(
        freqs >= freq_broad[0], freqs <= freq_broad[1])
    dx = freqs[1] - freqs[0]
    feat['abspow'] = np.trapz(psd[:, idx_broad], dx=dx)

    # Calculate entropy and fractal dimension features
    feat['perm'] = np.apply_along_axis(
        ant.perm_entropy, axis=1, arr=epochs, normalize=True)
    feat['higuchi'] = np.apply_along_axis(
        ant.higuchi_fd, axis=1, arr=epochs)
    feat['petrosian'] = ant.petrosian_fd(epochs, axis=1)

    # Convert to dataframe
    features = []
    feat = pd.DataFrame(feat)
    features.append(feat)

    # Save features to dataframe
    features = pd.concat(features, axis=1)
    features.index.name = 'epoch'

    # Downcast float64 to float32 (to reduce size of training datasets)
    cols_float = features.select_dtypes(np.float64).columns.tolist()
    features[cols_float] = features[cols_float].astype(np.float32)

    # Sort the column names here (same behavior as lightGBM)
    features.sort_index(axis=1, inplace=True)
    return features

# %%
# define parameters for feature extraction
# range of frequency band
freq_broad = (1, 90)
# window second
win_sec = 2
# each individual band
bands = [
    (1, 4, 'Delta'), (4, 8, 'Theta'), (8, 12, 'Alpha'), 
    (12, 20, 'lBeta'), (20, 30, 'hBeta'), (30, 45, 'lGamma'), (55, 90, 'hGamma')
]
# first downsample rate
# We did two times of down sampling because we recorded the data using 500 or 1000 Hz
# The first down sampling is to make sure all data have the same sampling rate
# And the second is to reducing computational load
fs_first = 500
# second downsample rate
fs_second = 200
# define window and parameters for psd comuputation
win = int(win_sec * fs_second)
kwargs_welch = dict(window='hamming', nperseg=win, average='median')

# %% [markdown]
# # import demo data

# %%
# define parameters for data preprocessing
# data_folder_path
data_folder = r'D:\a big_decoding_local_temporary\github代码上传'
data_name = 'demo_data.npy'
data = np.load('%s\%s' %(data_folder, data_name))

# %%
# LFP data were downsampled to 200 Hz during preprocessing
# shape of data (epoch in 30 seconds, channel, time point: 200 Hz * 30 seconds)
data.shape
# Out:
# (199, 1, 6000)

# %% [markdown]
# # import BGOOSE model

# %%
# set parameters for model loading
# model_file_path
model_folder = r'D:\a big_decoding_local_temporary\github代码上传'
model_name = 'final_model2312.joblib'
model = load('%s\%s' %(model_folder, model_name))

# %% [markdown]
# # run the prediction

# %%
# filter the data into different frequency bands
epochs_filter = filter_data(data.squeeze(), fs_second, 
                      l_freq=freq_broad[0], h_freq=freq_broad[1], verbose=False)
# get features matrix
features = feature_lfp(epochs_filter, fs_second, bands, kwargs_welch, freq_broad)
# load the machine learning model
model = load('%s\%s' %(model_folder, model_name))
# set the input array
X = np.array(features.iloc[:,0:28]).astype(np.float32)
# get the predictions
predict = model.predict(X)
# collect the sleep stages label
sleep_stage = []
for i in predict:
    if i == 0:
        sleep_stage += ['Wake']
    if i == 1:
        sleep_stage += ['Sleep-NREM']
    if i == 2:
        sleep_stage += ['Sleep-REM']
# report the results
for i in range(len(sleep_stage)):
    print ('The stage for your epoch [%s] is [%s]'%(str(i), sleep_stage[i]))
# Out:
# The stage for your epoch [0] is [Sleep-NREM]
# The stage for your epoch [1] is [Sleep-NREM]
# The stage for your epoch [2] is [Wake]
# The stage for your epoch [3] is [Wake]
# The stage for your epoch [4] is [Wake]
# The stage for your epoch [5] is [Sleep-NREM]
# The stage for your epoch [6] is [Sleep-NREM]
# The stage for your epoch [7] is [Wake]
# The stage for your epoch [8] is [Wake]
# The stage for your epoch [9] is [Wake]
# The stage for your epoch [10] is [Wake]
# The stage for your epoch [11] is [Wake]
# The stage for your epoch [12] is [Wake]
# The stage for your epoch [13] is [Sleep-NREM]
# The stage for your epoch [14] is [Wake]
# The stage for your epoch [15] is [Wake]
# The stage for your epoch [16] is [Sleep-NREM]
# The stage for your epoch [17] is [Sleep-NREM]
# The stage for your epoch [18] is [Wake]
# The stage for your epoch [19] is [Sleep-NREM]
# The stage for your epoch [20] is [Wake]
# The stage for your epoch [21] is [Wake]
# The stage for your epoch [22] is [Wake]
# The stage for your epoch [23] is [Wake]
# The stage for your epoch [24] is [Sleep-NREM]
# The stage for your epoch [25] is [Sleep-NREM]
# The stage for your epoch [26] is [Sleep-NREM]
# The stage for your epoch [27] is [Sleep-NREM]
# The stage for your epoch [28] is [Wake]
# The stage for your epoch [29] is [Sleep-NREM]
# The stage for your epoch [30] is [Sleep-NREM]
# The stage for your epoch [31] is [Sleep-NREM]
# The stage for your epoch [32] is [Wake]
# The stage for your epoch [33] is [Sleep-NREM]
# The stage for your epoch [34] is [Sleep-NREM]
# The stage for your epoch [35] is [Wake]
# The stage for your epoch [36] is [Wake]
# The stage for your epoch [37] is [Sleep-NREM]
# The stage for your epoch [38] is [Wake]
# The stage for your epoch [39] is [Wake]
# The stage for your epoch [40] is [Sleep-NREM]
# The stage for your epoch [41] is [Sleep-NREM]
# The stage for your epoch [42] is [Sleep-NREM]
# The stage for your epoch [43] is [Sleep-NREM]
# The stage for your epoch [44] is [Sleep-NREM]
# The stage for your epoch [45] is [Wake]
# The stage for your epoch [46] is [Sleep-NREM]
# The stage for your epoch [47] is [Wake]
# The stage for your epoch [48] is [Wake]
# The stage for your epoch [49] is [Wake]
# The stage for your epoch [50] is [Sleep-NREM]
# The stage for your epoch [51] is [Wake]
# The stage for your epoch [52] is [Sleep-NREM]
# The stage for your epoch [53] is [Sleep-NREM]
# The stage for your epoch [54] is [Sleep-NREM]
# The stage for your epoch [55] is [Wake]
# The stage for your epoch [56] is [Sleep-NREM]
# The stage for your epoch [57] is [Wake]
# The stage for your epoch [58] is [Wake]
# The stage for your epoch [59] is [Wake]
# The stage for your epoch [60] is [Wake]
# The stage for your epoch [61] is [Wake]
# The stage for your epoch [62] is [Sleep-NREM]
# The stage for your epoch [63] is [Sleep-NREM]
# The stage for your epoch [64] is [Wake]
# The stage for your epoch [65] is [Wake]
# The stage for your epoch [66] is [Wake]
# The stage for your epoch [67] is [Sleep-NREM]
# The stage for your epoch [68] is [Wake]
# The stage for your epoch [69] is [Wake]
# The stage for your epoch [70] is [Sleep-NREM]
# The stage for your epoch [71] is [Sleep-NREM]
# The stage for your epoch [72] is [Sleep-NREM]
# The stage for your epoch [73] is [Wake]
# The stage for your epoch [74] is [Sleep-NREM]
# The stage for your epoch [75] is [Sleep-REM]
# The stage for your epoch [76] is [Sleep-REM]
# The stage for your epoch [77] is [Wake]
# The stage for your epoch [78] is [Sleep-NREM]
# The stage for your epoch [79] is [Sleep-NREM]
# The stage for your epoch [80] is [Sleep-REM]
# The stage for your epoch [81] is [Sleep-NREM]
# The stage for your epoch [82] is [Sleep-NREM]
# The stage for your epoch [83] is [Sleep-NREM]
# The stage for your epoch [84] is [Sleep-NREM]
# The stage for your epoch [85] is [Sleep-NREM]
# The stage for your epoch [86] is [Sleep-NREM]
# The stage for your epoch [87] is [Sleep-NREM]
# The stage for your epoch [88] is [Sleep-NREM]
# The stage for your epoch [89] is [Sleep-NREM]
# The stage for your epoch [90] is [Sleep-NREM]
# The stage for your epoch [91] is [Sleep-NREM]
# The stage for your epoch [92] is [Sleep-NREM]
# The stage for your epoch [93] is [Sleep-NREM]
# The stage for your epoch [94] is [Sleep-NREM]
# The stage for your epoch [95] is [Sleep-NREM]
# The stage for your epoch [96] is [Sleep-NREM]
# The stage for your epoch [97] is [Sleep-NREM]
# The stage for your epoch [98] is [Sleep-NREM]
# The stage for your epoch [99] is [Sleep-NREM]
# The stage for your epoch [100] is [Sleep-NREM]
# The stage for your epoch [101] is [Sleep-NREM]
# The stage for your epoch [102] is [Sleep-NREM]
# The stage for your epoch [103] is [Sleep-NREM]
# The stage for your epoch [104] is [Sleep-NREM]
# The stage for your epoch [105] is [Sleep-NREM]
# The stage for your epoch [106] is [Sleep-NREM]
# The stage for your epoch [107] is [Sleep-NREM]
# The stage for your epoch [108] is [Sleep-NREM]
# The stage for your epoch [109] is [Sleep-NREM]
# The stage for your epoch [110] is [Sleep-NREM]
# The stage for your epoch [111] is [Sleep-NREM]
# The stage for your epoch [112] is [Sleep-NREM]
# The stage for your epoch [113] is [Sleep-NREM]
# The stage for your epoch [114] is [Sleep-NREM]
# The stage for your epoch [115] is [Sleep-NREM]
# The stage for your epoch [116] is [Sleep-NREM]
# The stage for your epoch [117] is [Sleep-NREM]
# The stage for your epoch [118] is [Sleep-NREM]
# The stage for your epoch [119] is [Sleep-NREM]
# The stage for your epoch [120] is [Sleep-NREM]
# The stage for your epoch [121] is [Sleep-NREM]
# The stage for your epoch [122] is [Sleep-NREM]
# The stage for your epoch [123] is [Sleep-NREM]
# The stage for your epoch [124] is [Sleep-NREM]
# The stage for your epoch [125] is [Sleep-NREM]
# The stage for your epoch [126] is [Sleep-NREM]
# The stage for your epoch [127] is [Sleep-NREM]
# The stage for your epoch [128] is [Sleep-NREM]
# The stage for your epoch [129] is [Sleep-NREM]
# The stage for your epoch [130] is [Sleep-NREM]
# The stage for your epoch [131] is [Sleep-NREM]
# The stage for your epoch [132] is [Sleep-NREM]
# The stage for your epoch [133] is [Sleep-NREM]
# The stage for your epoch [134] is [Sleep-NREM]
# The stage for your epoch [135] is [Sleep-NREM]
# The stage for your epoch [136] is [Sleep-NREM]
# The stage for your epoch [137] is [Sleep-REM]
# The stage for your epoch [138] is [Sleep-NREM]
# The stage for your epoch [139] is [Sleep-NREM]
# The stage for your epoch [140] is [Sleep-NREM]
# The stage for your epoch [141] is [Sleep-REM]
# The stage for your epoch [142] is [Sleep-NREM]
# The stage for your epoch [143] is [Wake]
# The stage for your epoch [144] is [Sleep-NREM]
# The stage for your epoch [145] is [Sleep-NREM]
# The stage for your epoch [146] is [Sleep-NREM]
# The stage for your epoch [147] is [Sleep-NREM]
# The stage for your epoch [148] is [Wake]
# The stage for your epoch [149] is [Sleep-NREM]
# The stage for your epoch [150] is [Sleep-NREM]
# The stage for your epoch [151] is [Wake]
# The stage for your epoch [152] is [Sleep-NREM]
# The stage for your epoch [153] is [Wake]
# The stage for your epoch [154] is [Wake]
# The stage for your epoch [155] is [Sleep-REM]
# The stage for your epoch [156] is [Sleep-NREM]
# The stage for your epoch [157] is [Sleep-NREM]
# The stage for your epoch [158] is [Wake]
# The stage for your epoch [159] is [Sleep-NREM]
# The stage for your epoch [160] is [Wake]
# The stage for your epoch [161] is [Sleep-NREM]
# The stage for your epoch [162] is [Sleep-NREM]
# The stage for your epoch [163] is [Sleep-NREM]
# The stage for your epoch [164] is [Sleep-REM]
# The stage for your epoch [165] is [Sleep-NREM]
# The stage for your epoch [166] is [Sleep-REM]
# The stage for your epoch [167] is [Sleep-REM]
# The stage for your epoch [168] is [Sleep-NREM]
# The stage for your epoch [169] is [Wake]
# The stage for your epoch [170] is [Sleep-REM]
# The stage for your epoch [171] is [Sleep-NREM]
# The stage for your epoch [172] is [Sleep-REM]
# The stage for your epoch [173] is [Sleep-REM]
# The stage for your epoch [174] is [Wake]
# The stage for your epoch [175] is [Sleep-NREM]
# The stage for your epoch [176] is [Sleep-NREM]
# The stage for your epoch [177] is [Wake]
# The stage for your epoch [178] is [Wake]
# The stage for your epoch [179] is [Sleep-NREM]
# The stage for your epoch [180] is [Sleep-REM]
# The stage for your epoch [181] is [Sleep-NREM]
# The stage for your epoch [182] is [Wake]
# The stage for your epoch [183] is [Wake]
# The stage for your epoch [184] is [Wake]
# The stage for your epoch [185] is [Sleep-NREM]
# The stage for your epoch [186] is [Sleep-REM]
# The stage for your epoch [187] is [Wake]
# The stage for your epoch [188] is [Sleep-NREM]
# The stage for your epoch [189] is [Sleep-NREM]
# The stage for your epoch [190] is [Sleep-REM]
# The stage for your epoch [191] is [Sleep-REM]
# The stage for your epoch [192] is [Sleep-REM]
# The stage for your epoch [193] is [Sleep-REM]
# The stage for your epoch [194] is [Sleep-REM]
# The stage for your epoch [195] is [Sleep-NREM]
# The stage for your epoch [196] is [Sleep-REM]
# The stage for your epoch [197] is [Sleep-REM]
# The stage for your epoch [198] is [Sleep-REM]
